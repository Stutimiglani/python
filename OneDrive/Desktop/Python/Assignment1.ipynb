# %%
# ASSIGNMENT NUMBER 1
# NAME: Stuti Miglani
# GF202570282


# 1. Write and run the small statement
print("Hello! My name is Stuti Miglani and my hobby is sketching.")


# 2. Print the comments
# This is a comment
print("Comments are used to explain the code.")


# 3. Display integer, float, String and Boolean
integer_value = 25
float_value = 12.5
string_value = "Python"
boolean_value = True

print("Integer:", integer_value)
print("Float:", float_value)
print("String:", string_value)
print("Boolean:", boolean_value)


# 4. Convert float to integer, String to integer, Boolean to integer
float_number = 10.5
string_number = "20"
boolean_value = True

print("Float to integer:", int(float_number))
print("String to integer:", int(string_number))
print("Boolean to integer:", int(boolean_value))


# 5. Simple calculator operations
a = 20
b = 10

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)


# 6. Calculate how many hours there are in 160 minutes
minutes = 160
hours = minutes / 60

print("Hours in 160 minutes:", hours)
# Out:
# Hello! My name is Stuti Miglani and my hobby is sketching.
# Comments are used to explain the code.
# Integer: 25
# Float: 12.5
# String: Python
# Boolean: True
# Float to integer: 10
# String to integer: 20
# Boolean to integer: 1
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0
# Hours in 160 minutes: 2.6666666666666665
