# %%
# ASSIGNMENT NUMBER 2
# NAME: Stuti Miglani
# GF202570282

# 1. Creating an empty list
_list = []
print(_list)


# 2. Storing the items in shopping list
_list = ["watch", "laptop", "shoes", "pen", "clothes"]
print(_list)


# 3. Adding new item Football to the shopping list
_list.append("football")
print(_list)


# 4. Printing the last item from the shopping list
print("last item:", _list[-1])


# 5. Printing the entire shopping list
print("shopping list:", _list)


# 6. Printing important items like laptop and shoes
print("important items:", _list[1], "and", _list[2])


# 7. Changing the item: Instead of pen, now I want to buy notebook
_list[3] = "notebook"
print("shopping list:", _list)


# 8. Printing the entire shopping list by deleting the least important item
# Assuming watch is the least important item
del _list[0]
print("shopping list after deleting least important item:", _list)
# Out:
# []
# ['watch', 'laptop', 'shoes', 'pen', 'clothes']
# ['watch', 'laptop', 'shoes', 'pen', 'clothes', 'football']
# last item: football
# shopping list: ['watch', 'laptop', 'shoes', 'pen', 'clothes', 'football']
# important items: laptop and shoes
# shopping list: ['watch', 'laptop', 'shoes', 'notebook', 'clothes', 'football']
# shopping list after deleting least important item: ['laptop', 'shoes', 'notebook', 'clothes', 'football']
